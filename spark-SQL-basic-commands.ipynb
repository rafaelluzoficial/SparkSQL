# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *

spark.sql("CREATE DATABASE DESPACHANTE")
spark.sql("SHOW DATABASES").show()

# apontando para o BD no qual se deseja trabalhar
spark.sql("USE DESPACHANTE").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-646393311335748> in <module>
#       2 from pyspark.sql.types import *
#       3
# ----> 4 spark.sql("CREATE DATABASE DESPACHANTE")
#       5 spark.sql("SHOW DATABASES").show()
#       6
#
# /databricks/spark/python/pyspark/sql/session.py in sql(self, sqlQuery)
#     775         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     776         """
# --> 777         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     778
#     779     def table(self, tableName):
#
# /databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     121                 # Hide where the exception came from that shows a non-Pythonic
#     122                 # JVM exception message.
# --> 123                 raise converted from None
#     124             else:
#     125                 raise
#
# AnalysisException: org.apache.hadoop.hive.metastore.api.AlreadyExistsException: Database despachante already exists

# %%
# Criando um DF e carregando em uma tabela do BD
arqSchema = "id INT, nome STRING, status STRING, cidade STRING, vendas INT, data STRING"
path_dataset = '/FileStore/tables/despachantes.csv'

# Lê arquivos formato CSV
df_despachantes1 = spark.read.csv(path_dataset, header=False, schema=arqSchema)
df_despachantes1.show()

# Carregando dados do DF na tabela do BD
df_despachantes1.write.saveAsTable("Despachantes")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+---+-------------------+------+-------------+------+----------+
#  id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
#   1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
#   2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
#   3|   Em&iacute;dio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
#   4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
#   5|     Gra&ccedil;a Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
#   6|   Matilde Rebou&ccedil;as| Ativo| Porto Alegre|    22|2019-01-05|
#   7|    No&ecirc;mia   Orri&ccedil;a| Ativo|  Santa Maria|    45|2019-10-05|
#   8|      Roque V&aacute;squez| Ativo| Porto Alegre|    65|2020-03-05|
#   9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
#  10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# +---+-------------------+------+-------------+------+----------+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-4462673795210058> in <module>
#       8
#       9 # Carregando dados do DF na tabela do BD
# ---> 10 df_despachantes1.write.saveAsTable("Despachantes")
#
# /databricks/spark/python/pyspark/sql/readwriter.py in saveAsTable(self, name, format, mode, partitionBy, **options)
#    1183         if format is not None:
#    1184             self.format(format)
# -> 1185         self._jwrite.saveAsTable(name)
#    1186
#    1187     def json(self, path, mode=None, compression=None, dateFormat=None, timestampFormat=None,
#
# /databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     121                 # Hide where the exception came from that shows a non-Pythonic
#     122                 # JVM exception message.
# --> 123                 raise converted from None
#     124             else:
#     125                 raise
#
# AnalysisException: Table despachante.Despachantes already exists

# %%
# Carregando dados do DF na tabela do BD no modo sobrescrever tabela
df_despachantes1.write.mode("overwrite").saveAsTable("Despachantes")

# Carregando dados do DF na tabela do BD no modo adicionar novos dados
# df_despachantes1.write.mode("append").saveAsTable("Despachantes")

spark.sql("SHOW TABLES").show()
spark.sql("SELECT * FROM Despachantes").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----------+------------+-----------+
#    database|   tableName|isTemporary|
# +-----------+------------+-----------+
# despachante|despachantes|      false|
# +-----------+------------+-----------+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+---+-------------------+------+-------------+------+----------+
#  id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
#   1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
#   2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
#   3|   Em&iacute;dio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
#   4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
#   5|     Gra&ccedil;a Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
#   6|   Matilde Rebou&ccedil;as| Ativo| Porto Alegre|    22|2019-01-05|
#   7|    No&ecirc;mia   Orri&ccedil;a| Ativo|  Santa Maria|    45|2019-10-05|
#   8|      Roque V&aacute;squez| Ativo| Porto Alegre|    65|2020-03-05|
#   9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
#  10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# +---+-------------------+------+-------------+------+----------+
#
# </div>

# %%
# Criando DF com consultas SQL
df_despachantes2 = spark.sql("SELECT * FROM Despachantes")
df_despachantes2.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+---+-------------------+------+-------------+------+----------+
#  id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
#   1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
#   2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
#   3|   Em&iacute;dio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
#   4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
#   5|     Gra&ccedil;a Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
#   6|   Matilde Rebou&ccedil;as| Ativo| Porto Alegre|    22|2019-01-05|
#   7|    No&ecirc;mia   Orri&ccedil;a| Ativo|  Santa Maria|    45|2019-10-05|
#   8|      Roque V&aacute;squez| Ativo| Porto Alegre|    65|2020-03-05|
#   9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
#  10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# +---+-------------------+------+-------------+------+----------+
#
# </div>

# %%
# Criando uma tabela não gerenciada (externa ao BD)
df_despachantes2.write.option("path", "/FileStore/Despachante").saveAsTable("Despachantes_ng")
spark.sql("Despachantes_ng").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-4462673795210062> in <module>
#       1 # Criando uma tabela não gerenciada (externa ao BD)
# ----> 2 df_despachantes2.write.option("path", "/FileStore/Despachante").saveAsTable("Despachantes_ng")
#       3 spark.sql("Despachantes_ng").show()
#
# /databricks/spark/python/pyspark/sql/readwriter.py in saveAsTable(self, name, format, mode, partitionBy, **options)
#    1183         if format is not None:
#    1184             self.format(format)
# -> 1185         self._jwrite.saveAsTable(name)
#    1186
#    1187     def json(self, path, mode=None, compression=None, dateFormat=None, timestampFormat=None,
#
# /databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     121                 # Hide where the exception came from that shows a non-Pythonic
#     122                 # JVM exception message.
# --> 123                 raise converted from None
#     124             else:
#     125                 raise
#
# AnalysisException: Cannot create table ('`despachante`.`Despachantes_ng`'). The associated location ('/FileStore/Despachante') is not empty but it's not a Delta table

# %%
# Verificando se a tabela é gerenciada ou não

# Se no resultado aparecer o campo LOCATION com o path, não é gerenciada
spark.sql("SHOW CREATE TABLE Despachantes").show(truncate=False)
spark.sql("SHOW CREATE TABLE Despachantes_ng").show(truncate=False)

# A indicação de gerenciada está no campo tableType=MANAGED ou EXTERNAL
spark.catalog.listTables()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+------------------------------------------------------------------------------------------------------------------------------------------------------------+
# createtab_stmt                                                                                                                                              |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------+
# CREATE TABLE `despachante`.`Despachantes` (
#   `id` INT,
#   `nome` STRING,
#   `status` STRING,
#   `cidade` STRING,
#   `vendas` INT,
#   `data` STRING)
# USING delta
#
# +------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-4462673795210063> in <module>
#       3 # Se no resultado aparecer o campo LOCATION com o path, não é gerenciada
#       4 spark.sql("SHOW CREATE TABLE Despachantes").show(truncate=False)
# ----> 5 spark.sql("SHOW CREATE TABLE Despachantes_ng").show(truncate=False)
#       6
#       7 # A indicação de gerenciada está no campo tableType=MANAGED ou EXTERNAL
#
# /databricks/spark/python/pyspark/sql/session.py in sql(self, sqlQuery)
#     775         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     776         """
# --> 777         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     778
#     779     def table(self, tableName):
#
# /databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     121                 # Hide where the exception came from that shows a non-Pythonic
#     122                 # JVM exception message.
# --> 123                 raise converted from None
#     124             else:
#     125                 raise
#
# AnalysisException: Table or permanent view not found for 'SHOW CREATE TABLE': Despachantes_ng; line 1 pos 0;
# 'ShowCreateTable false
# +- 'UnresolvedTableOrView [Despachantes_ng], SHOW CREATE TABLE, false

# %%
# Criando Views

# View temporária
# df_despachantes2.createOrReplaceTempView("vw_despachantes2")
spark.sql("SELECT * FROM vw_despachantes2").show()

# View Global
# df_despachantes2.createOrReplaceGlobalTempView("vw_g_despachantes2")
spark.sql("SELECT * FROM global_temp.vw_g_despachantes2").show()

# Criação via SparkSQL
# spark.sql("CREATE OR REPLACE TEMP VIEW vw_despachantes3 AS SELECT * FROM Despachantes")
spark.sql("SELECT * FROM vw_despachantes3").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+---+-------------------+------+-------------+------+----------+
#  id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
#   1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
#   2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
#   3|   Em&iacute;dio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
#   4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
#   5|     Gra&ccedil;a Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
#   6|   Matilde Rebou&ccedil;as| Ativo| Porto Alegre|    22|2019-01-05|
#   7|    No&ecirc;mia   Orri&ccedil;a| Ativo|  Santa Maria|    45|2019-10-05|
#   8|      Roque V&aacute;squez| Ativo| Porto Alegre|    65|2020-03-05|
#   9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
#  10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# +---+-------------------+------+-------------+------+----------+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+---+-------------------+------+-------------+------+----------+
#  id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
#   1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
#   2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
#   3|   Em&iacute;dio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
#   4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
#   5|     Gra&ccedil;a Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
#   6|   Matilde Rebou&ccedil;as| Ativo| Porto Alegre|    22|2019-01-05|
#   7|    No&ecirc;mia   Orri&ccedil;a| Ativo|  Santa Maria|    45|2019-10-05|
#   8|      Roque V&aacute;squez| Ativo| Porto Alegre|    65|2020-03-05|
#   9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
#  10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# +---+-------------------+------+-------------+------+----------+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+---+-------------------+------+-------------+------+----------+
#  id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
#   1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
#   2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
#   3|   Em&iacute;dio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
#   4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
#   5|     Gra&ccedil;a Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
#   6|   Matilde Rebou&ccedil;as| Ativo| Porto Alegre|    22|2019-01-05|
#   7|    No&ecirc;mia   Orri&ccedil;a| Ativo|  Santa Maria|    45|2019-10-05|
#   8|      Roque V&aacute;squez| Ativo| Porto Alegre|    65|2020-03-05|
#   9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
#  10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# +---+-------------------+------+-------------+------+----------+
#
# </div>

# %%
# Trabalhando com JOINS
# Joins entre tabelas Despachantes e Reclamacoes

# rec_Schema = "idrec INT, datarec STRING, iddesp INT"
# reclamacoes = spark.read.csv("/FileStore/tables/reclamacoes.csv", header=False, schema=rec_Schema)

# reclamacoes.write.saveAsTable("Reclamacoes")
spark.sql("SELECT * FROM Reclamacoes").show()
spark.sql("SELECT * FROM Despachantes").show()

df_despachantes1.join(reclamacoes, df_despachantes1.id == reclamacoes.iddesp, "inner").select("idrec", "datarec", "iddesp", "nome").show()
spark.sql("SELect Reclamacoes.*, Despachantes.nome FROM Despachantes INNER JOIN Reclamacoes ON (Despachantes.id = Reclamacoes.iddesp) ORDER BY Reclamacoes.iddesp").show()

df_despachantes1.join(reclamacoes, df_despachantes1.id == reclamacoes.iddesp, "left").select("idrec", "datarec", "iddesp", "nome").show()
spark.sql("SELect Reclamacoes.*, Despachantes.nome FROM Despachantes LEFT JOIN Reclamacoes ON (Despachantes.id = Reclamacoes.iddesp) ORDER BY Reclamacoes.iddesp").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----+----------+------+
# idrec|   datarec|iddesp|
# +-----+----------+------+
#     1|2020-09-12|     2|
#     2|2020-09-11|     2|
#     3|2020-10-05|     4|
#     4|2020-10-02|     5|
#     5|2020-12-06|     5|
#     6|2020-01-09|     5|
#     7|2020-01-05|     9|
# +-----+----------+------+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+---+-------------------+------+-------------+------+----------+
#  id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
#   1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
#   2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
#   3|   Em&iacute;dio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
#   4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
#   5|     Gra&ccedil;a Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
#   6|   Matilde Rebou&ccedil;as| Ativo| Porto Alegre|    22|2019-01-05|
#   7|    No&ecirc;mia   Orri&ccedil;a| Ativo|  Santa Maria|    45|2019-10-05|
#   8|      Roque V&aacute;squez| Ativo| Porto Alegre|    65|2020-03-05|
#   9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
#  10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# +---+-------------------+------+-------------+------+----------+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----+----------+------+-------------------+
# idrec|   datarec|iddesp|               nome|
# +-----+----------+------+-------------------+
#     2|2020-09-11|     2|    Deolinda Vilela|
#     1|2020-09-12|     2|    Deolinda Vilela|
#     3|2020-10-05|     4|Felisbela Dornelles|
#     6|2020-01-09|     5|     Gra&ccedil;a Ornellas|
#     5|2020-12-06|     5|     Gra&ccedil;a Ornellas|
#     4|2020-10-02|     5|     Gra&ccedil;a Ornellas|
#     7|2020-01-05|     9|      Uriel Queiroz|
# +-----+----------+------+-------------------+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----+----------+------+-------------------+
# idrec|   datarec|iddesp|               nome|
# +-----+----------+------+-------------------+
#     1|2020-09-12|     2|    Deolinda Vilela|
#     2|2020-09-11|     2|    Deolinda Vilela|
#     3|2020-10-05|     4|Felisbela Dornelles|
#     5|2020-12-06|     5|     Gra&ccedil;a Ornellas|
#     6|2020-01-09|     5|     Gra&ccedil;a Ornellas|
#     4|2020-10-02|     5|     Gra&ccedil;a Ornellas|
#     7|2020-01-05|     9|      Uriel Queiroz|
# +-----+----------+------+-------------------+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----+----------+------+-------------------+
# idrec|   datarec|iddesp|               nome|
# +-----+----------+------+-------------------+
#  null|      null|  null|   Carminda Pestana|
#     2|2020-09-11|     2|    Deolinda Vilela|
#     1|2020-09-12|     2|    Deolinda Vilela|
#  null|      null|  null|   Em&iacute;dio Dornelles|
#     3|2020-10-05|     4|Felisbela Dornelles|
#     6|2020-01-09|     5|     Gra&ccedil;a Ornellas|
#     5|2020-12-06|     5|     Gra&ccedil;a Ornellas|
#     4|2020-10-02|     5|     Gra&ccedil;a Ornellas|
#  null|      null|  null|   Matilde Rebou&ccedil;as|
#  null|      null|  null|    No&ecirc;mia   Orri&ccedil;a|
#  null|      null|  null|      Roque V&aacute;squez|
#     7|2020-01-05|     9|      Uriel Queiroz|
#  null|      null|  null|   Viviana Sequeira|
# +-----+----------+------+-------------------+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----+----------+------+-------------------+
# idrec|   datarec|iddesp|               nome|
# +-----+----------+------+-------------------+
#  null|      null|  null|   Matilde Rebou&ccedil;as|
#  null|      null|  null|    No&ecirc;mia   Orri&ccedil;a|
#  null|      null|  null|   Em&iacute;dio Dornelles|
#  null|      null|  null|      Roque V&aacute;squez|
#  null|      null|  null|   Viviana Sequeira|
#  null|      null|  null|   Carminda Pestana|
#     1|2020-09-12|     2|    Deolinda Vilela|
#     2|2020-09-11|     2|    Deolinda Vilela|
#     3|2020-10-05|     4|Felisbela Dornelles|
#     5|2020-12-06|     5|     Gra&ccedil;a Ornellas|
#     6|2020-01-09|     5|     Gra&ccedil;a Ornellas|
#     4|2020-10-02|     5|     Gra&ccedil;a Ornellas|
#     7|2020-01-05|     9|      Uriel Queiroz|
# +-----+----------+------+-------------------+
#
# </div>
